# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f = '../../data/Plantas termosolares México.xlsx'
df = pd.read_excel(f)
df
# Out:
#                                               Empresa           NOMEDO  \
# 0                           BEVCO, S. DE R.L. DE C.V.          Jalisco
# 1                             Casa Cuervo S.A de C.V.          Jalisco
# 2   Durango Dairy Company (Productos Lácteos COVBARS)          Durango
# 3                                      Lácteos Mojica          Jalisco
# 4                   NESTLE DAIRY PLANT CHAPA DE CORZO          Chiapas
# 5                  NESTLE DAIRY PLANT LAGOS DE MORENO          Jalisco
# 6                  Quesera Lacteos Ticoy, S.A. de C.V   Aguascalientes
# 7                                    Quesos La Doñita       Guanajuato
# 8   Solar Pasteurization (Lechera Guadalajara SELL...          Jalisco
# 9              Carnes Selectas de Sonora S.A. de C.V.          Jalisco
# 10        Centro Lechero Cooperativo de los Altos SCL          Jalisco
# 11          Casa Armando Guillermo Prieto S.A de C.V.           Oaxaca
# ...
