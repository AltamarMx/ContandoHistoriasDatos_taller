# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

# %%
def water(index, data, Title="", x_lab="", y_lab="",
              formatting = "{:,.1f}", green_color='#29EA38', red_color='#FB3C62', blue_color='#24CAFF',
             sorted_value = False, threshold=None, other_label='other', net_label='net', 
             rotation_value = 30, blank_color=(0,0,0,0), figsize = (10.871,5.515)):
    '''
    Given two sequences ordered appropriately, generate a standard waterfall chart.
    Optionally modify the title, axis labels, number formatting, bar colors, 
    increment sorting, and thresholding. Thresholding groups lower magnitude changes
    into a combined group to display as a single entity on the chart.
    '''
    
    #convert data and index to np.array
    index=np.array(index)
    data=np.array(data)
    
    # wip
    #sorted by absolute value 
    if sorted_value: 
        abs_data = abs(data)
        data_order = np.argsort(abs_data)[::-1]
        data = data[data_order]
        index = index[data_order]
    
    #group contributors less than the threshold into 'other' 
    if threshold:
        
        abs_data = abs(data)
        threshold_v = abs_data.max()*threshold
        
        if threshold_v > abs_data.min():
            index = np.append(index[abs_data>=threshold_v],other_label)
            data = np.append(data[abs_data>=threshold_v],sum(data[abs_data<threshold_v]))
    
    changes = {'amount' : data}
    
    #define format formatter
    def money(x, pos):
        'The two args are the value and tick position'
        return formatting.format(x)
    formatter = FuncFormatter(money)
    
    fig, ax = plt.subplots(figsize=figsize)
    ax.yaxis.set_major_formatter(formatter)

    #Store data and create a blank series to use for the waterfall
    trans = pd.DataFrame(data=changes,index=index)
    blank = trans.amount.cumsum().shift(1).fillna(0)
    
    trans['positive'] = trans['amount'] > 0

    #Get the net total number for the final element in the waterfall
    total = trans.sum().amount
    trans.loc[net_label]= total
    blank.loc[net_label] = total

    #The steps graphically show the levels as well as used for label placement
    step = blank.reset_index(drop=True).repeat(3).shift(-1)
    step[1::3] = np.nan

    #When plotting the last element, we want to show the full bar,
    #Set the blank to 0
    blank.loc[net_label] = 0
    
    #define bar colors for net bar
    trans.loc[trans['positive'] > 1, 'positive'] = 99
    trans.loc[trans['positive'] < 0, 'positive'] = 99
    trans.loc[(trans['positive'] > 0) & (trans['positive'] < 1), 'positive'] = 99
    
    trans['color'] = trans['positive']
    
    trans.loc[trans['positive'] == 1, 'color'] = green_color
    trans.loc[trans['positive'] == 0, 'color'] = red_color
    trans.loc[trans['positive'] == 99, 'color'] = blue_color
    
    my_colors = list(trans.color)
    
    #Plot and label
    my_plot = plt.bar(range(0,len(trans.index)), blank, width=0.5, color=blank_color)
    plt.bar(range(0,len(trans.index)), trans.amount, width=0.6,
             bottom=blank, color=my_colors)       
                                   
    
    # connecting lines - figure out later
    #my_plot = lines.Line2D(step.index, step.values, color = "gray")
    #my_plot = lines.Line2D((3,3), (4,4))
    
    #axis labels
    plt.xlabel("\n" + x_lab)
    plt.ylabel(y_lab + "\n")

    #Get the y-axis position for the labels
    y_height = trans.amount.cumsum().shift(1).fillna(0)
    
    temp = list(trans.amount)
    
    # create dynamic chart range
    for i in range(len(temp)):
        if (i > 0) & (i < (len(temp) - 1)):
            temp[i] = temp[i] + temp[i-1]
    
    trans['temp'] = temp
            
    plot_max = trans['temp'].max()
    plot_min = trans['temp'].min()
    
    #Make sure the plot doesn't accidentally focus only on the changes in the data
    if all(i >= 0 for i in temp):
        plot_min = 0
    if all(i < 0 for i in temp):
        plot_max = 0
    
    if abs(plot_max) >= abs(plot_min):
        maxmax = abs(plot_max)   
    else:
        maxmax = abs(plot_min)
        
    pos_offset = maxmax / 40
    
    plot_offset = maxmax / 15 ## needs to me cumulative sum dynamic

    #Start label loop
    loop = 0
    for index, row in trans.iterrows():
        # For the last item in the list, we don't want to double count
        if row['amount'] == total:
            y = y_height[loop]
        else:
            y = y_height[loop] + row['amount']
        # Determine if we want a neg or pos offset
        if row['amount'] > 0:
            y += (pos_offset*2)
            plt.annotate(formatting.format(row['amount']),(loop,y),ha="center", color = 'k', fontsize=12)
        else:
            y -= (pos_offset*4)
            plt.annotate(formatting.format(row['amount']),(loop,y),ha="center", color = 'k', fontsize=12)
        loop+=1

    #Scale up the y axis so there is room for the labels
    plt.ylim(plot_min-round(3.6*plot_offset, 7),plot_max+round(3.6*plot_offset, 7))
    
    #Rotate the labels
    plt.xticks(range(0,len(trans)), trans.index, rotation=rotation_value)
    
    #add zero line and title
    plt.axhline(0, color='black', linewidth = 0.6, linestyle="dashed")
    plt.title(Title)
    plt.tight_layout()

    return fig, ax

# %%
f = '../../data/Plantas termosolares México.xlsx'
df = pd.read_excel(f,index_col=5)
df.sort_index(inplace=True)
df
# Out:
#                                                                Empresa  \
# Inicio de operación
# 2012.0                                        Lacto Productos El Indio
# 2013.0                                                  Matatlan Dairy
# 2013.0                                           Buenavista Greenhouse
# 2013.0               Durango Dairy Company (Productos Lácteos COVBARS)
# 2014.0               Biotecnología Mexicana de Microalgas S.A. de C.V.
# 2014.0                                                Quesos La Doñita
# 2014.0                                                Nutrición Marina
# 2014.0                              NESTLE DAIRY PLANT LAGOS DE MORENO
# 2014.0                               NESTLE DAIRY PLANT CHAPA DE CORZO
# 2014.0                              Enfriadora Jaliciense S.A. de C.V.
# 2015.0               Solar Pasteurization (Lechera Guadalajara SELL...
# 2015.0                          Carnes Selectas de Sonora S.A. de C.V.
# 2015.0                     Centro Lechero Cooperativo de los Altos SCL
# 2015.0                                       Destilería 501 S.A de C.V
# 2015.0                                                  Rastro Garibay
# 2015.0                                             Canels S.A. de C.V.
# 2015.0                     Procesadora de Alimentos Integrales - PAISA
# 2015.0                         Agropecuaria Tarasca S. de P.R. de R.L.
# 2015.0                              Quesera Lacteos Ticoy, S.A. de C.V
# 2016.0                                                  Lácteos Mojica
# 2016.0               Sustentabilidad de Energía y Medio Ambiente S....
# 2017.0                       Alimentos y Productos para Ganado Lechero
# 2017.0                                                Quesos la Ordeña
# 2017.0                                       BEVCO, S. DE R.L. DE C.V.
# 2017.0                                            COMFOSA, S.A de C.V.
# 2017.0                                                    Agrana Fruit
# 2017.0                                  Jacona de Plancarte, Michoacán
# 2017.0                                   Valle de Santiago, Guanajuato
# 2017.0                           Capilla de Guadalupe, Jalisco, Mexico
# 2017.0                                             Mochicahui, Sinaloa
# 2017.0                                         Mérida, Yucatán, Mexico
# 2017.0                          Tlacolula de Matamoros, Oaxaca, Mexico
# 2017.0                                    Guadalajara, Jalisco, Mexico
# 2017.0                                            Teocaltiche, Jalisco
# 2018.0                                       Jiutepec, Morelos, Mexico
# 2018.0               Blvd. Luis Encinas J, Calle Av. Rosales &, Cen...
# 2019.0                                                             NaN
#
#                            Lat         Lon                           Uso  \
# Inicio de operación
# 2012.0                     NaN         NaN         other process heating
# 2013.0                     NaN         NaN    general processing heating
# 2013.0                     NaN         NaN  heating of producction halls
# 2013.0               24.033543 -104.686407                Pasteurización
# 2014.0                     NaN         NaN    general processing heating
# 2014.0                     NaN         NaN                Pasteurización
# 2014.0                     NaN         NaN                       Cooking
# 2014.0               21.368154 -101.922474                Pasteurización
# 2014.0               16.706989  -93.002907                Pasteurización
# 2014.0                     NaN         NaN         other process heating
# 2015.0                     NaN         NaN                Pasteurización
# 2015.0                     NaN         NaN                      Cleaning
# 2015.0                     NaN         NaN                      Cleaning
# 2015.0                     NaN         NaN  Evaporation and destillation
# 2015.0                     NaN         NaN         other process heating
# 2015.0                     NaN         NaN            coolling processes
# 2015.0                     NaN         NaN                       Cooking
# 2015.0                     NaN         NaN         other process heating
# 2015.0                     NaN         NaN                Pasteurización
# 2016.0               20.645761 -103.357762                Pasteurización
# 2016.0                     NaN         NaN         other process heating
# 2017.0                     NaN         NaN    general processing heating
# 2017.0                     NaN         NaN         other process heating
# 2017.0               20.674144 -103.330171                Pasteurización
# 2017.0                     NaN         NaN         other process heating
# 2017.0                     NaN         NaN         other process heating
# 2017.0                     NaN         NaN                       Cooking
# 2017.0                     NaN         NaN                       Cooking
# 2017.0                     NaN         NaN                       Cooking
# 2017.0                     NaN         NaN                       Cooking
# 2017.0                     NaN         NaN  Evaporation and destillation
# 2017.0               20.611882 -103.418921                Pasteurización
# 2017.0                     NaN         NaN         other process heating
# 2018.0                     NaN         NaN         other process heating
# 2018.0                     NaN         NaN    general processing heating
# 2019.0                     NaN         NaN                           NaN
#
#                                  Nombre del colector  \
# Inicio de operación
# 2012.0                              Power Trough 110
# 2013.0                              Power Trough 110
# 2013.0                              Power Trough 110
# 2013.0                              Power Trough 110
# 2014.0                              Power Trough 110
# 2014.0                              Power Trough 110
# 2014.0                              Power Trough 110
# 2014.0                              Power Trough 110
# 2014.0                              Power Trough 110
# 2014.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2015.0                              Power Trough 110
# 2016.0                              Power Trough 110
# 2017.0               short-term water storage               24.4
# 2017.0               short-term water storage                3.0
# 2017.0               short-term water storage                2.5
# 2017.0               short-term water storage               15.2
# 2017.0               short-term water storage                9.0
# 2017.0               short-term water storage                9.6
# 2017.0               short-term water storage                5.0
# 2017.0               short-term water storage                9.0
# 2017.0                                  other               0.15
# 2017.0               short-term water storage                9.9
# 2017.0               short-term water storage                9.6
# 2017.0                steam accumulation tank                4.8
# 2018.0                        sin información                5.0
# 2018.0                no solar energy storage                NaN
# 2019.0                        sin información    sin información
#
#                     Kind of conventional heat source Kind of fuel used
# Inicio de operación
# 2012.0                                  steam boiler          fuel oil
# 2013.0                                  steam boiler             other
# 2013.0                              hot water boiler       natural gas
# 2013.0                                  steam boiler          fuel oil
# 2014.0                                           NaN               NaN
# 2014.0                              hot water boiler       natural gas
# 2014.0                                  steam boiler          fuel oil
# 2014.0                                  steam boiler       natural gas
# 2014.0                                  steam boiler             other
# 2014.0                              hot water boiler             other
# 2015.0                                  steam boiler       natural gas
# 2015.0                              hot water boiler             other
# 2015.0                              hot water boiler             other
# 2015.0                              hot water boiler             other
# 2015.0                                  steam boiler             other
# 2015.0                                  steam boiler       natural gas
# 2015.0                                  steam boiler             other
# 2015.0                              hot water boiler             other
# 2015.0                                  steam boiler             other
# 2016.0                              hot water boiler             other
# 2016.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                                         other       natural gas
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler             other
# 2017.0                              hot water boiler       natural gas
# 2018.0                                  steam boiler             other
# 2018.0                              hot water boiler       natural gas
# 2019.0                               sin información             other

# %%
df.columns
# Out:
# Index(['Empresa', 'NOMEDO', 'Estado', 'Lat', 'Lon', 'Uso',
#        'Nombre del colector', 'Tipo de colector', 'Area instalada (gross), m2',
#        'Área instalada (apertura), m2', 'Installed thermal power , kWth',
#        'Solar collector loop heat transfer fluid', 'Solar energy storage',
#        'Storage volume, m³', 'Kind of conventional heat source',
#        'Kind of fuel used'],
#       dtype='object')

# %%
df.groupby(by=['NOMEDO',"Inicio de operación"]).sum()[["Installed thermal power , kWth"]]
# Out:
#                                      Installed thermal power , kWth
# NOMEDO          Inicio de operación
# Aguascalientes  2015.0                                        42.00
# Baja California 2017.0                                       179.85
# Chiapas         2014.0                                       126.00
#                 2017.0                                        35.34
# D.F.            2016.0                                        27.11
# Durango         2013.0                                        46.20
# Guanajuato      2014.0                                        22.20
#                 2017.0                                        92.61
# Jalisco         2013.0                                        82.20
#                 2014.0                                       231.39
#                 2015.0                                       610.70
#                 2016.0                                        59.88
#                 2017.0                                       465.87
# Michoacan       2012.0                                        74.00
#                 2015.0                                       126.30
#                 2017.0                                       112.85
# Morelos         2018.0                                       110.88
# Oaxaca          2017.0                                       136.79
# San Luis Potosi 2015.0                                       118.00
# Sinaloa         2014.0                                        97.20
#                 2017.0                                       104.81
# Sonora          2018.0                                       177.80
# Yucatan         2017.0                                        77.90

# %%
df.groupby(by=["Inicio de operación",'NOMEDO',]).sum()[["Installed thermal power , kWth"]]
# Out:
#                                      Installed thermal power , kWth
# Inicio de operación NOMEDO
# 2012.0              Michoacan                                 74.00
# 2013.0              Durango                                   46.20
#                     Jalisco                                   82.20
# 2014.0              Chiapas                                  126.00
#                     Guanajuato                                22.20
#                     Jalisco                                  231.39
#                     Sinaloa                                   97.20
# 2015.0              Aguascalientes                            42.00
#                     Jalisco                                  610.70
#                     Michoacan                                126.30
#                     San Luis Potosi                          118.00
# 2016.0              D.F.                                      27.11
#                     Jalisco                                   59.88
# 2017.0              Baja California                          179.85
#                     Chiapas                                   35.34
#                     Guanajuato                                92.61
#                     Jalisco                                  465.87
#                     Michoacan                                112.85
#                     Oaxaca                                   136.79
#                     Sinaloa                                  104.81
#                     Yucatan                                   77.90
# 2018.0              Morelos                                  110.88
#                     Sonora                                   177.80

# %%
df['Installed thermal power , kWth'].groupby(by=[df.index]).sum().cumsum()
# Out:
# Inicio de operación
# 2012.0      74.00
# 2013.0     202.40
# 2014.0     679.19
# 2015.0    1576.19
# 2016.0    1663.18
# 2017.0    2869.20
# 2018.0    3157.88
# 2019.0    3423.88
# Name: Installed thermal power , kWth, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,6))

ps = df['Installed thermal power , kWth'].groupby(by=[df.index]).sum().cumsum()

ax.plot(ps,'-o')

# %%
a = df['Installed thermal power , kWth'].groupby(by=[df.index]).sum().index.to_list()
a  = [str(int(A)) for A in a]

b = df['Installed thermal power , kWth'].groupby(by=[df.index]).sum().to_list()

# %%
a
# Out:
# ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
b
# Out:
# [74.0,
#  128.4,
#  476.78999999999996,
#  897.0,
#  86.99000000000001,
#  1206.02,
#  288.68,
#  266.0]

# %%
# colores
azulier        = "#1A3D6F"
naranjaier     = '#C65C25'
amarilloclaro  = '#f6ec7f'
naranja        = '#d8a700'

fig, ax = water(a, b, 
         rotation_value=0, 
         sorted_value=False,
         formatting="{:,.0f}",
         net_label='Total',
         other_label='Peor año',
         blue_color=naranja, 
         green_color=amarilloclaro, 
         red_color='blue')
ax.set_title('Potencia térmica instalada en México')
ax.set_ylabel('Potencia (kWh)')
ax.set_xlabel('Año')

ax.spines[['right', 'top']].set_visible(False)
# Out:
# C:\Users\gbv\AppData\Local\Temp\ipykernel_7148\341716435.py:53: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   trans.loc[net_label]= total
