# %%
# %matplotlib inline
import matplotlib.pyplot as mp
import pandas as pd
import numpy as np

# %%
f  = "../data/temixco temperaturas.txt"
nombres = ["tiempo","Tmax","Tmin"]

df = pd.read_csv(f,encoding ="iso-8859-1", skiprows = 18,
                 delim_whitespace = True , usecols =[0,3,4],
                 names = nombres,na_values ="Nulo")
df.tiempo = pd.to_datetime(df.tiempo,format = "%d/%m/%Y")
df.set_index("tiempo", inplace =True)
df
# Out:
#             Tmax  Tmin
# tiempo
# 1957-04-01  33.0  10.0
# 1957-04-02  32.0  14.5
# 1957-04-03  32.0  13.5
# 1957-04-04  34.0  13.5
# 1957-04-05  34.5  10.0
# ...          ...   ...
# 2016-08-27  31.0  17.0
# 2016-08-28  30.0  17.0
# 2016-08-29  29.0  18.0
# 2016-08-30  29.0  17.0
# 2016-08-31  31.0  17.0
#
# [21429 rows x 2 columns]

# %%
df.index
# Out:
# DatetimeIndex(['1957-04-01', '1957-04-02', '1957-04-03', '1957-04-04',
#                '1957-04-05', '1957-04-06', '1957-04-07', '1957-04-08',
#                '1957-04-09', '1957-04-10',
#                ...
#                '2016-08-22', '2016-08-23', '2016-08-24', '2016-08-25',
#                '2016-08-26', '2016-08-27', '2016-08-28', '2016-08-29',
#                '2016-08-30', '2016-08-31'],
#               dtype='datetime64[ns]', name='tiempo', length=21429, freq=None)

# %%
df.plot(figsize=(15,10),)
# Out:
# <AxesSubplot:xlabel='tiempo'>

# %%
 df.Tmax.resample("Y").max().plot(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='tiempo'>
