# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
f  = "../../data/Precios_combustible.csv"

df = pd.read_csv(f,skiprows=[0],names=["fecha","reg","prem","diesel"])
df.fecha = pd.to_datetime(df.fecha,format="%d/%m/%Y")
df.reg = df.reg.str.replace(",",".").astype("float")
df.prem = df.prem.str.replace(",",".").astype("float")
df.diesel = df.diesel.str.replace(",",".").astype("float")
df.set_index("fecha",inplace=True)
df = df.sort_index()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2250 entries, 2017-01-01 to 2023-02-28
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   reg     2250 non-null   float64
#  1   prem    2250 non-null   float64
#  2   diesel  2250 non-null   float64
# dtypes: float64(3)
# memory usage: 70.3 KB

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot( df.diesel) 
ax.plot( df.reg)
ax.plot( df.prem)
